# %%
#更改圖片檔檔名
import os
aim_file=r"C:\Users\st030\birdphoto\2\valid\images"
start_name=470
files=os.listdir(aim_file)
for filename in files:
    if filename == files[0]:
        oldname = os.path.join(aim_file,filename)
        newname = os.path.join(aim_file,f'{start_name}.jpg')
        os.rename(oldname,newname)
    else:
        oldname = os.path.join(aim_file,filename)
        start_name += 1
        newname = os.path.join(aim_file,f'{start_name}.jpg')
        os.rename(oldname,newname)
    print(f'{filename} was changed to {newname}')
# Out:
# 100--6-_jpg.rf.4a0b97b436fb947a4d230e8b46525d97.jpg was changed to C:\Users\st030\birdphoto\2\valid\images\470.jpg
# 1005_jpg.rf.4d757698bc697280855d52a895d85755.jpg was changed to C:\Users\st030\birdphoto\2\valid\images\471.jpg
# 100_jpg.rf.1438fb4f52e096af50934a83efc65dc7.jpg was changed to C:\Users\st030\birdphoto\2\valid\images\472.jpg
# 101--5-_jpg.rf.f7ebf414759f75d9b22c789688c1e6d9.jpg was changed to C:\Users\st030\birdphoto\2\valid\images\473.jpg
# 101--6-_jpg.rf.843f55a42aea7d4448bd08ad3d1a809c.jpg was changed to C:\Users\st030\birdphoto\2\valid\images\474.jpg
# 1014_jpg.rf.bfa38be8ad81b51986f9a81e4c1e4784.jpg was changed to C:\Users\st030\birdphoto\2\valid\images\475.jpg
# 1015_jpg.rf.d900428173e1e32891f1b2d1cf436ece.jpg was changed to C:\Users\st030\birdphoto\2\valid\images\476.jpg
# 102--7-_jpg.rf.b6536170eb28ece8fca95c432bd500c3.jpg was changed to C:\Users\st030\birdphoto\2\valid\images\477.jpg
# ...

# %%
#更改label檔檔名
import os
aim_file=r"C:\Users\st030\birdphoto\2\valid\labels"
start_name=470
files=os.listdir(aim_file)
for filename in files:
    if filename == files[0]:
        oldname = os.path.join(aim_file,filename)
        newname = os.path.join(aim_file,f'{start_name}.txt')
        os.rename(oldname,newname)
    else:
        oldname = os.path.join(aim_file,filename)
        start_name += 1
        newname = os.path.join(aim_file,f'{start_name}.txt')
        os.rename(oldname,newname)
    print(f'{filename} was changed to {newname}')
# Out:
# 100--6-_jpg.rf.4a0b97b436fb947a4d230e8b46525d97.txt was changed to C:\Users\st030\birdphoto\2\valid\labels\470.txt
# 1005_jpg.rf.4d757698bc697280855d52a895d85755.txt was changed to C:\Users\st030\birdphoto\2\valid\labels\471.txt
# 100_jpg.rf.1438fb4f52e096af50934a83efc65dc7.txt was changed to C:\Users\st030\birdphoto\2\valid\labels\472.txt
# 101--5-_jpg.rf.f7ebf414759f75d9b22c789688c1e6d9.txt was changed to C:\Users\st030\birdphoto\2\valid\labels\473.txt
# 101--6-_jpg.rf.843f55a42aea7d4448bd08ad3d1a809c.txt was changed to C:\Users\st030\birdphoto\2\valid\labels\474.txt
# 1014_jpg.rf.bfa38be8ad81b51986f9a81e4c1e4784.txt was changed to C:\Users\st030\birdphoto\2\valid\labels\475.txt
# 1015_jpg.rf.d900428173e1e32891f1b2d1cf436ece.txt was changed to C:\Users\st030\birdphoto\2\valid\labels\476.txt
# 102--7-_jpg.rf.b6536170eb28ece8fca95c432bd500c3.txt was changed to C:\Users\st030\birdphoto\2\valid\labels\477.txt
# ...

# %%
import os

image_dir = r"C:\Users\st030\birdphoto\1\train\images"
label_dir = r"C:\Users\st030\birdphoto\1\train\labels"
missing_labels = []
for image_file in os.listdir(image_dir):
    if image_file.endswith(".jpg"):
        label_file = os.path.join(label_dir, image_file.replace(".jpg", ".txt"))
        if not os.path.exists(label_file):
            missing_labels.append(image_file)

if missing_labels:
    print(f"Missing labels for {len(missing_labels)} images: {missing_labels}...")
else:
    print("All images have corresponding labels.")
# Out:
# Missing labels for 861 images: ['30734.jpg', '30747.jpg', '30758.jpg', '30759.jpg', '30772.jpg', '30790.jpg', '30807.jpg', '30853.jpg', '30894.jpg', '30922.jpg', '30941.jpg', '30944.jpg', '30968.jpg', '30973.jpg', '30997.jpg', '31001.jpg', '31026.jpg', '31062.jpg', '31070.jpg', '31080.jpg', '31081.jpg', '31086.jpg', '31104.jpg', '31106.jpg', '31108.jpg', '31123.jpg', '31130.jpg', '31143.jpg', '31155.jpg', '31163.jpg', '31177.jpg', '31188.jpg', '31216.jpg', '31217.jpg', '31230.jpg', '31239.jpg', '31240.jpg', '31241.jpg', '31246.jpg', '31253.jpg', '31268.jpg', '31272.jpg', '31275.jpg', '31281.jpg', '31284.jpg', '31346.jpg', '31367.jpg', '31395.jpg', '31421.jpg', '31432.jpg', '31437.jpg', '31446.jpg', '31449.jpg', '31465.jpg', '31491.jpg', '31506.jpg', '31508.jpg', '31572.jpg', '31621.jpg', '31643.jpg', '31648.jpg', '31667.jpg', '31686.jpg', '31696.jpg', '31700.jpg', '31714.jpg', '31727.jpg', '31785.jpg', '31792.jpg', '31798.jpg', '31834.jpg', '31837.jpg', '31843.jpg', '31846.jpg', '318
# ...

# %%
from ultralytics import YOLOv10
from ultralytics import utils
import seaborn as sns
import matplotlib as plt
from sklearn.metrics import precision_recall_curve,confusion_matrix,auc

model = YOLOv10('yolov10x.pt')
model.train(data='data.yaml',epochs=250,batch=32,imgsz=160,device='cuda',max_det=100)
# Out:
# New https://pypi.org/project/ultralytics/8.3.62 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.19 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
from ultralytics import YOLOv10
from ultralytics import utils
model=YOLOv10('yolov10s.pt')
model.train(data='data.yaml',epochs=250,batch=32,imgsz=160,lr0=0.001,device='cuda',optimizer='AdamW')
# Out:
# New https://pypi.org/project/ultralytics/8.3.59 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.19 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
from ultralytics import YOLOv10
from ultralytics import utils
model=YOLOv10('yolov10x.pt')
model.train(data='data.yaml',epochs=250,batch=32,imgsz=160,lr0=0.001,cos_lr=True,device='cuda',optimizer='AdamW',box=15)
# Out:
# New https://pypi.org/project/ultralytics/8.3.62 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.19 torch-2.0.1 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %%
from ultralytics import YOLOv10
from ultralytics import utils

model = YOLOv10('')
model.val(data='data.yaml', batch=256)
